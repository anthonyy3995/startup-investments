# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
offices_df = pd.read_csv('offices.csv')
offices_df.head()
# Out:
#    id object_id  office_id   description   region            address1  \
# 0   1       c:1          1           NaN  Seattle    710 - 2nd Avenue
# 1   2       c:3          3  Headquarters   SF Bay     4900 Hopyard Rd
# 2   3       c:4          4           NaN   SF Bay  135 Mississippi St
# 3   4       c:5          5  Headquarters   SF Bay    1601 Willow Road
# 4   5       c:7          7           NaN   SF Bay           Suite 200
#
#           address2           city zip_code state_code country_code   latitude  \
# 0       Suite 1100        Seattle    98104         WA          USA  47.603122
# 1        Suite 310     Pleasanton    94588         CA          USA  37.692934
# 2              NaN  San Francisco    94107         CA          USA  37.764726
# 3              NaN     Menlo Park    94025         CA          USA  37.416050
# 4  654 High Street      Palo Alto    94301         CA          ISR   0.000000
#
#     longitude  created_at  updated_at
# ...

# %%
offices_df.description
# Out:
# 0                  NaN
# 1         Headquarters
# 2                  NaN
# 3         Headquarters
# 4                  NaN
#               ...
# 112713             NaN
# 112714             NaN
# 112715             NaN
# 112716             NaN
# 112717             NaN
# Name: description, Length: 112718, dtype: object

# %%
company_city_df = offices_df[["office_id", "city"]]

# %%
funding_rounds_df = pd.read_csv("funding_rounds.csv")
raised_amount_df = funding_rounds_df[["object_id", "raised_amount_usd"]]

# %%
total_raised_df = raised_amount_df.groupby(["object_id"]).sum().reset_index()
total_raised_df
# Out:
#       object_id  raised_amount_usd
# 0           c:1         39750000.0
# 1        c:1001          5000000.0
# 2       c:10014                0.0
# 3       c:10015         68069200.0
# 4      c:100155         10125293.0
# ...         ...                ...
# 31934   c:99853           500000.0
# 31935    c:9989          1100000.0
# 31936    c:9994           500000.0
# 31937    c:9995           750000.0
# 31938    c:9998           475000.0
#
# [31939 rows x 2 columns]

# %%
company_city_df
# Out:
#         office_id           city
# 0               1        Seattle
# 1               3     Pleasanton
# 2               4  San Francisco
# 3               5     Menlo Park
# 4               7      Palo Alto
# ...           ...            ...
# 112713     127846      Greenwich
# 112714     127847  Santa Barbara
# 112715     127848    Los Angeles
# 112716     127849       New York
# 112717     127850      San Mateo
#
# [112718 rows x 2 columns]

# %%
merged_df = company_city_df.merge(total_raised_df, left_on = 'office_id', right_on="object_id", how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4290ae612e64> in <module>
# ----> 1 merged_df = company_city_df.merge(total_raised_df, left_on = 'office_id', right_on="object_id", how="inner")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
# ...

# %%
city_avg_df = merged_df.groupby(["city"]).mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-19ec8e8a90af> in <module>
# ----> 1 city_avg_df = merged_df.groupby(["city"]).mean().reset_index()
#
# NameError: name 'merged_df' is not defined

# %%
#now try same with only USA
df_usa = offices_df[offices_df.country_code == "USA"]
print(df_usa)
# Out:
#             id object_id  office_id   description         region  \
# 0            1       c:1          1           NaN        Seattle
# 1            2       c:3          3  Headquarters         SF Bay
# 2            3       c:4          4           NaN         SF Bay
# 3            4       c:5          5  Headquarters         SF Bay
# 5            6       c:8          8           NaN         SF Bay
# ...        ...       ...        ...           ...            ...
# 112713  112714   f:15098     127846           NaN       New York
# 112714  112715  c:286200     127847           NaN  Santa Barbara
# 112715  112716  c:256895     127848           NaN    Los Angeles
# 112716  112717  c:256200     127849           NaN       New York
# 112717  112718  c:286215     127850           NaN         SF Bay
#
#                                   address1    address2           city  \
# 0                         710 - 2nd Avenue  Suite 1100        Seattle
# ...
